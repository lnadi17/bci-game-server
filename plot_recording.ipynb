# %%
import mne
import matplotlib.pyplot as plt

# %%
# Path to the .fif file
file_path = 'recordings/recording_5df4.raw.fif'

# %%
# Read the raw data
raw = mne.io.read_raw_fif(file_path, preload=True)
# Out:
# Opening raw data file recordings/recording_5df4.raw.fif...
#     Range : 0 ... 20479 =      0.000 ...    19.999 secs
# Ready.
# Reading 0 ... 20479  =      0.000 ...    19.999 secs...

# %%
# Print raw data info
raw.info
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: Fp1, Fpz, Fp2, F7, F3, Fz, F4, F8, FC5, FC1, FC2, FC6, M1, T7, ...
#  chs: 63 EEG, 2 EOG, 1 Galvanic skin response, 1 ECG, 1 Stimulus
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 512.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 68
#  projs: []
#  sfreq: 1024.0 Hz
# >

# %%
# Observe annotations
annotations = raw.annotations
annotations
# Out:
# <Annotations | 14 segments: Annotation 1 (5), Annotation 2 (4), Annotation ...>

# %%
# Plot the raw data (only the first 10 seconds)
raw.crop(tmin=0, tmax=10).plot()
plt.show()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
